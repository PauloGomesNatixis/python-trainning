# %%
## Challenge

import pandas as pd

#Use the `offers.csv` file.
# Load the file into a DataFrame.
# Load the CSV file into a DataFrame
df = pd.read_csv('./csv/offers.csv')

# Display the first few rows of the DataFrame
#print(df.head())
df
# Out:
#                            offer_id     offer_type  difficulty  reward  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo          10      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo          10      10
# 2  3f207df678b143eea3cee63160fa8bed  informational           0       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo           5       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount          20       5
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount           7       3
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount          10       2
# 7  5a8bc65990b245e5a138643cd4eb9837  informational           0       0
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo           5       5
# 9  2906b810c7d4411798c6938adc9daaa5       discount          10       2
#
#    duration                              channels
# 0         7         ['email', 'mobile', 'social']
# 1         5  ['web', 'email', 'mobile', 'social']
# ...

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('./csv/offers.csv')

# Display the first few rows of the DataFrame
#print(df.head())

#- Filter the DataFrame to show only the `bogo` offers.
# Assuming 'offer_type' is the column that indicates the type of offer
bogo_offers = df[df['offer_type'] == 'bogo']

# Display the filtered DataFrame
#print(bogo_offers)
bogo_offers
# Out:
#                            offer_id offer_type  difficulty  reward  duration  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd       bogo          10      10         7
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0       bogo          10      10         5
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9       bogo           5       5         7
# 8  f19421c1d4aa40978ebb69ca19b0e20d       bogo           5       5         5
#
#                                channels
# 0         ['email', 'mobile', 'social']
# 1  ['web', 'email', 'mobile', 'social']
# 3            ['web', 'email', 'mobile']
# 8  ['web', 'email', 'mobile', 'social']

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('./csv/offers.csv')

#- Create a new column called `total_reward` that multiplies the `reward` by the `difficulty`.
# Assuming 'reward' and 'difficulty' are the names of the relevant columns
df['total_reward'] = df['reward'] * df['difficulty']

# Display the updated DataFrame
#print(df.head())
df.head()
# Out:
#                            offer_id     offer_type  difficulty  reward  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo          10      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo          10      10
# 2  3f207df678b143eea3cee63160fa8bed  informational           0       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo           5       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount          20       5
#
#    duration                              channels  total_reward
# 0         7         ['email', 'mobile', 'social']           100
# 1         5  ['web', 'email', 'mobile', 'social']           100
# 2         4            ['web', 'email', 'mobile']             0
# 3         7            ['web', 'email', 'mobile']            25
# 4        10                      ['web', 'email']           100

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('./csv/offers.csv')

#- Create a new column called `reward_per_day` that divides the `total_reward` by the `duration`.
# Create the total_reward column
df['total_reward'] = df['reward'] * df['difficulty']

# Create the reward_per_day column
df['reward_per_day'] = df['total_reward'] / df['duration']

# Display the updated DataFrame
df.head()
# Out:
#                            offer_id     offer_type  difficulty  reward  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo          10      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo          10      10
# 2  3f207df678b143eea3cee63160fa8bed  informational           0       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo           5       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount          20       5
#
#    duration                              channels  total_reward  \
# 0         7         ['email', 'mobile', 'social']           100
# 1         5  ['web', 'email', 'mobile', 'social']           100
# 2         4            ['web', 'email', 'mobile']             0
# 3         7            ['web', 'email', 'mobile']            25
# 4        10                      ['web', 'email']           100
#
#    reward_per_day
# 0       14.285714
# 1       20.000000
# 2        0.000000
# 3        3.571429
# 4       10.000000

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('./csv/offers.csv')

# Create the total_reward column
df['total_reward'] = df['reward'] * df['difficulty']

# Create the reward_per_day column
df['reward_per_day'] = df['total_reward'] / df['duration']

# Display the updated DataFrame
#df.head()

#- Save the transformed DataFrame to a new CSV file.
df.to_csv('transformed_offers.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the transformed DataFrame
df = pd.read_csv('transformed_offers.csv')

# Create a bar plot for reward_per_day
plt.figure(figsize=(10, 6))
plt.bar(df['offer_id'], df['reward_per_day'], color='skyblue')
plt.xlabel('Offer ID')
plt.ylabel('Reward Per Day')
plt.title('Reward Per Day by Offer ID')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
